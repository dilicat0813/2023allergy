# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/data_total.csv')

# %%
df.isnull().sum()
#1. 바코드 nan --> 알수없음
#2. capacity nan --> 알수없음
#3, seller --> 알수없음
#4. 영양 --> 알수 없음
#5. prdkindstate --> 알수 없음
#6. prdkind --> 알수없음
#allergy 19 null--> 채우던가, -처리하던가 좌측 성분으로 대체(drop 가능성도 고려)
# Out:
# rnum                0
# prdlstReportNo      0
# productGb           0
# prdlstNm            0
# rawmtrl             0
# allergy            19
# prdkind             1
# prdkindstate        2
# manufacture         0
# imgurl1             0
# imgurl2             0
# nutrient          300
# seller            194
# barcode           321
# capacity          367
# dtype: int64

# %%
df_allergy = df[['rnum','allergy']]

# %%
df_allergy = pd.DataFrame(df_allergy)

# %%
#전처리
df_allergy = df_allergy.fillna('알수없음')
df_allergy['allergy2'] = df_allergy['allergy']
df_allergy['allergy2'] = df_allergy['allergy2'].str.replace('함유식품', '')
df_allergy['allergy2'] = df_allergy['allergy2'].str.replace(' 함유', '')
df_allergy['allergy2'] = df_allergy['allergy2'].str.replace('함유', '')
df_allergy['allergy2'] = df_allergy['allergy2'].str.replace('쇠고기', '소고기')
df_allergy['allergy2'] = df_allergy['allergy2'].str.replace('이제품은우유,대두를사용한제품과같은제조시설에서제조하고있습니다.', '우유, 대두')
df_allergy['allergy2'] = df_allergy['allergy2'].str.replace('본 제품은 새우,오징어를 원료로 사용한 제품과 같은 제조시설에서 제조하고 있습니다.', '새우, 오징어')

import re #조개류 통일
pattern = r'조개류\([^\)]+\)'
df_allergy['allergy3'] = [re.sub(pattern, '조개류', s) for s in df_allergy['allergy2']]
df_allergy
#알러지3칼럼만 사용
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_22704\685254646.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_allergy['allergy2'] = df_allergy['allergy2'].str.replace('이제품은우유,대두를사용한제품과같은제조시설에서제조하고있습니다.', '우유, 대두')
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_22704\685254646.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_allergy['allergy2'] = df_allergy['allergy2'].str.replace('본 제품은 새우,오징어를 원료로 사용한 제품과 같은 제조시설에서 제조하고 있습니다.', '새우, 오징어')

# %%
df_allergy[df_allergy['allergy2'].str.contains('조개류')] #조사용
# Out:
#         rnum                                allergy  \
# 116      117            쇠고기,돼지고기,대두,우유,밀,토마토,조개류(굴)
# 217      218         대두, 밀, 쇠고기, 새우, 조개류(굴, 바지락) 함유
# 218      219              대두, 밀, 새우, 조개류(굴, 바지락) 함유
# 219      220              대두, 밀, 쇠고기, 조개류(굴), 새우 포함
# 240      241                         우유,대두,밀,조개류(굴)
# ...      ...                                    ...
# 14801  14802  돼지고기,쇠고기,닭고기,대두,우유,계란,밀,토마토,조개류(굴) 함유
# 14816  14817  돼지고기,쇠고기,닭고기,대두,우유,계란,밀,토마토,조개류(굴) 함유
# 14818  14819     돼지고기,쇠고기,닭고기,대두,우유,밀,토마토,조개류(굴) 함류
# 14851  14852     우유,대두,밀,게,새우,계란,쇠고기,오징어,조개류(홍합) 함유
# 14854  14855         밀,대두,계란,우유,돼지고기,닭고기,쇠고기,조개류 함유
#
#                                  allergy2                         allergy3
# 116           소고기,돼지고기,대두,우유,밀,토마토,조개류(굴)         소고기,돼지고기,대두,우유,밀,토마토,조개류
# 217           대두, 밀, 소고기, 새우, 조개류(굴, 바지락)              대두, 밀, 소고기, 새우, 조개류
# 218                대두, 밀, 새우, 조개류(굴, 바지락)                   대두, 밀, 새우, 조개류
# 219             대두, 밀, 소고기, 조개류(굴), 새우 포함           대두, 밀, 소고기, 조개류, 새우 포함
# 240                        우유,대두,밀,조개류(굴)                      우유,대두,밀,조개류
# ...                                   ...                              ...
# 14801  돼지고기,소고기,닭고기,대두,우유,계란,밀,토마토,조개류(굴)  돼지고기,소고기,닭고기,대두,우유,계란,밀,토마토,조개류
# 14816  돼지고기,소고기,닭고기,대두,우유,계란,밀,토마토,조개류(굴)  돼지고기,소고기,닭고기,대두,우유,계란,밀,토마토,조개류
# 14818  돼지고기,소고기,닭고기,대두,우유,밀,토마토,조개류(굴) 함류  돼지고기,소고기,닭고기,대두,우유,밀,토마토,조개류 함류
# 14851     우유,대두,밀,게,새우,계란,소고기,오징어,조개류(홍합)      우유,대두,밀,게,새우,계란,소고기,오징어,조개류
# 14854         밀,대두,계란,우유,돼지고기,닭고기,소고기,조개류      밀,대두,계란,우유,돼지고기,닭고기,소고기,조개류
#
# [517 rows x 4 columns]

# %%
# ',' 로 구분된 열들을 분리하여 리스트로 변환
allergy_list = df_allergy['allergy3'].str.split(',')

# 리스트를 바탕으로 새로운 열들을 생성
new_columns = ['allergy_{}'.format(i+1) for i in range(allergy_list.str.len().max())]
new_df = df_allergy.assign(**{col: allergy_list.str[i] for i, col in enumerate(new_columns)}) #대충 분리가능한지 검토

# %%
new_df[new_df['allergy_20'].notnull()] #아래 있는 것들은 아마도 성분 그냥 때려박은 것으로 보임
# Out:
#       rnum                                            allergy  \
# 6262  6263  [호두쿠키] 밀,우유,계란,호두\n[통밀크래커] 밀,우유,계란\n[코코넛쿠키] 밀,...
# 7714  7715  현미유과 : 대두\n흑미유과 : 대두\n녹차유과 : 대두\n백련초 유과 : 대두\n...
#
#                                                allergy2  \
# 6262  [호두쿠키] 밀,우유,계란,호두\n[통밀크래커] 밀,우유,계란\n[코코넛쿠키] 밀,...
# 7714  현미유과 : 대두\n흑미유과 : 대두\n녹차유과 : 대두\n백련초 유과 : 대두\n...
#
#                                                allergy3  \
# 6262  [호두쿠키] 밀,우유,계란,호두\n[통밀크래커] 밀,우유,계란\n[코코넛쿠키] 밀,...
# 7714  현미유과 : 대두\n흑미유과 : 대두\n녹차유과 : 대두\n백련초 유과 : 대두\n...
#
#                                               allergy_1      allergy_2  \
# 6262                                           [호두쿠키] 밀             우유
# 7714  현미유과 : 대두\n흑미유과 : 대두\n녹차유과 : 대두\n백련초 유과 : 대두\n...  대두\n교동약과 : 우유
#
#      allergy_3       allergy_4 allergy_5        allergy_6  ...     allergy_11  \
# 6262        계란   호두\n[통밀크래커] 밀        우유    계란\n[코코넛쿠키] 밀  ...  호두\n[초코아몬드] 밀
# 7714         밀  대두\n고시볼-콩 : 우유         밀  대두\n고시볼-흑미 : 우유  ...              밀
#
#            allergy_12                allergy_13       allergy_14  \
# 6262               우유  계란\n[보리쿠키] 우유\n[단호박쿠키] 밀               우유
# 7714  대두\n화이트 흑미 : 우유                         밀  대두\n화이트 호박 : 우유
#
#          allergy_15       allergy_16 allergy_17        allergy_18 allergy_19  \
# 6262  계란\n[검정콩쿠키] 밀               우유         계란     대두\n[검정깨스틱] 밀         우유
# 7714              밀  대두\n화이트 녹차 : 우유          밀  대두\n화이트 백년초 : 우유          밀
#
#                       allergy_20
# 6262                          계란
# 7714  대두\n참깨와흑콩 : 대두\n들깨와흑콩 : 대두
#
# [2 rows x 24 columns]
