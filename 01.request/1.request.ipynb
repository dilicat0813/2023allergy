# %%
# !pip install xmltodict

# %%
# Python3 샘플 코드 #
# key = 'SDqWmmlSMlsBobBnB0DwlV9IVwFkxNwn42%2BKrK%2F5WMV0AxecYPKMJ2tAurfLvCGOt2hvyBLvi9oG7R%2Bn%2FG4ZUA%3D%3D'
import openpyxl
import requests
import pandas as pd
import requests
import json
import xmltodict

#1~90, 91~152

df = pd.DataFrame()
for page in range(151,152):
    url = 'http://apis.data.go.kr/B553748/CertImgListService/getCertImgListService'
    params ={f'serviceKey' : 'SDqWmmlSMlsBobBnB0DwlV9IVwFkxNwn42+KrK/5WMV0AxecYPKMJ2tAurfLvCGOt2hvyBLvi9oG7R+n/G4ZUA==', 'returnType' : 'xml', 'pageNo' : {page}, 'numOfRows' : '100' }
    response = requests.get(url, params=params).content
    dict = xmltodict.parse(response)
    jsonString = json.dumps(dict['response']['body'], ensure_ascii=False)
    jsonobj = json.loads(jsonString)
    temp_df = pd.DataFrame(jsonobj['items']['item'])
    df = pd.concat([df, temp_df])
# for item in jsonobj['items']['item']:
    # print(item)
    # product_name.append(item['prdlstNm'])
    # rawmtrl.append(item['rawmtrl'])
    # allergy.append(item['allergy'])
    # prdkind.append(item['prdkind'])
    # prdkindstate.append(item['prdkindstate'])
    # manufacture.

# %%
df
# Out:
#      rnum   prdlstReportNo productGb      prdlstNm  \
# 0   15001   19690086003421        식품        에이비씨초코
# 1   15002   19690086003338        식품           빼빼로
# 2   15003   19690086003321        식품      롯데 후레쉬민트
# 3   15004   19690086003320        식품      롯데 스피아민트
# 4   15005  196900860031172        식품   자일리톨 x 2080
# ..    ...              ...       ...           ...
# 73  15074   19550509001219        식품        매일양념쌈장
# 74  15075   19550509001209        식품  매일맛있는신태양초고추장
# 75  15076   19550509001186        식품        오뚜기진간장
# 76  15077   19550509001185        식품        오뚜기국간장
# 77  15078    1955050900115        식품     매일맛있는신고추장
#
#                                               rawmtrl allergy  \
# 0   백설탕,코코아프리퍼레이션(수입산,전지분유(우유),코코아매스),식물성유지(수입산),코...    알수없음
# 1   밀가루(밀-수입산),백설탕,코코아매스(가나산-코코아빈),식물성유지,쇼트닝,유당(우유...    알수없음
# 2   백설탕,껌베이스(합성감미료(아세설팜칼륨,수크랄로스))분말,결정포도당,물엿,합성착향료...    알수없음
# 3   백설탕,껌베이스(합성감미료(아세설팜칼륨,수크랄로스)분말결정포도당,물엿,합성착향료(스...    알수없음
# ...

# %%
df.to_csv('data91-151.csv', index=False, encoding='utf-8-sig')

# %%
df1 = pd.read_csv('data.csv')
df2 = pd.read_csv('data91-151.csv')

# %%
df3 = pd.concat([df1, df2])
# Out:
#        rnum  prdlstReportNo productGb         prdlstNm  \
# 0         1    201904962715        식품       설화눈꽃팝김부각스낵
# 1         2    201904962712        식품  설화눈꽃팝김부각스낵 아몬드맛
# 2         3    201904962711        식품         눈꽃팝김부각스낵
# 3         4    201903787252        식품           참군고구마칩
# 4         5    201903787251        식품            참군고구마
# ...     ...             ...       ...              ...
# 6087  15088  19550509001219        식품           매일양념쌈장
# 6088  15089  19550509001209        식품     매일맛있는신태양초고추장
# 6089  15090  19550509001186        식품           오뚜기진간장
# 6090  15091  19550509001185        식품           오뚜기국간장
# 6091  15092   1955050900115        식품        매일맛있는신고추장
#
#                                                 rawmtrl allergy prdkind  \
# 0     찹쌀,김,참깨,옥수수기름(옥배유),양파,무,대파,천일염,마늘,새우,멸치,다시마,건표...      없음      과자
# 1     찹쌀,김,참깨,옥수수기름(옥배유),아몬드,양파,무,천일염,대파,마늘,새우,멸치,다시...     아몬드      과자
# 2     찹쌀,김,참깨,옥수수기름(옥배유),양파,무,대파,천일염,마늘,새우,멸치,다시마,건표...      없음      과자
# ...

# %%
df3.reset_index(drop=True, inplace=True)

# %%
df3.to_csv('data_total.csv', index=False, encoding='utf-8-sig')

# %%
df3.tail()
# Out:
#         rnum  prdlstReportNo productGb      prdlstNm  \
# 15087  15088  19550509001219        식품        매일양념쌈장
# 15088  15089  19550509001209        식품  매일맛있는신태양초고추장
# 15089  15090  19550509001186        식품        오뚜기진간장
# 15090  15091  19550509001185        식품        오뚜기국간장
# 15091  15092   1955050900115        식품     매일맛있는신고추장
#
#                                                  rawmtrl allergy prdkind  \
# 15087  된장63.15%[대두{수입산(미국산,중국산,캐나다산)},소맥분(밀:미국산,호주산),...    대두,밀     혼합장
# 15088  물엿,소맥분(밀:미국산,호주산),혼합양념(중국산)[고춧가루6.12%,(고추:중국산)...       밀     고추장
# 15089  탈지대두[수입산(인도산,미국산,중국산)],정제수,양조간장원액(대만산)[탈지대두,소맥...    대두,밀    혼합간장
# 15090  정제수,아미노산액[탈지대두:외국산(인도산,미국산,중국산등)],정제소금(국산),액상과...    대두,밀    혼합간장
# 15091  물엿, 소맥분(밀:미국산,호주산),혼합양념(중국산)[고춧가루6.12%(고추:중국산)...    알수없음     고추장
#
#       prdkindstate                 manufacture  \
# 15087         알수없음   매일식품㈜_전라남도 순천시 서면 산단1길 16
# 15088         알수없음  매일식품㈜_전라남도 순전시 서면 산단 1길 16
# 15089         알수없음   매일식품㈜_전라남도 순천시 서면 산단1길 16
# ...
