# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
from pandas.io.json import json_normalize
import json

# %%
df = pd.DataFrame()  # Create an empty DataFrame to store the results
url = 'http://openapi.foodsafetykorea.go.kr/api/32cb3ef9d10d40e3ad9d/COOKRCP01/json/1000/2000'
response = urlopen(url)
json_api = response.read().decode("utf-8")
json_file = json.loads(json_api)
data_list = json_file['COOKRCP01']['row']
df = df.append(json_normalize(data_list), ignore_index=True)
df
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_26284\717437628.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = df.append(json_normalize(data_list), ignore_index=True)
#                                         RCP_PARTS_DTLS RCP_WAY2 MANUAL_IMG20  \
# 0    얼갈이 배추 60g, 홍고추 0.6g [소스소개저나트륨 무침양념:두부 30g, 된장...      끓이기
# 1    •필수재료 : 오이(60g), 통마늘(3g), 생강(5g), 말린 홍고추(3g)\n...       기타
# 2    당면 20g, 등심얇게썬것 20g, 당근 5g, 표고버섯마른것 10g, 느타리버섯 ...       볶기
# 3    상추 10g, 오이 10g, 당근 5g, 비타민 5g, 방울토마토 10g, 쑥갓 2...       기타
# 4    청고추 10g, 깻잎 10g, 애호박 20g, 홍고추 5g, 밀가루 50g, 고추자...       굽기
# ..                                                 ...      ...          ...
# 110  [ 2인분 ] 마늘(4쪽), 토마토(2개), 양파(1개), 월계수잎(2장), 육수용...      끓이기
# 111  [ 2인분 ] 황금팽이버섯(400g), 양파( 개), 상추(2장), 깻잎(2장), ...       기타
# 112  [ 4인분 ] 미역 줄기(1팩=300g), 양파(½개), 맛살(135g), 건새우(...       굽기
# 113  [ 2인분 ] 새송이버섯(1개), 방울토마토(200g), 오징어(1마리), 칵테일새...       볶기
# 114  [ 2인분 ] 토마토(2개), 양파(¼개), 감자(¼개), 노랑 파프리카(¼개), ...       볶기
#
#     MANUAL20 RCP_SEQ INFO_NA INFO_WGT INFO_PRO MANUAL_IMG13 MANUAL_IMG14  ...  \
# 0                822     181               4.7                            ...
# 1                824      86       75      0.3                            ...
# 2                825     255               6.3                            ...
# 3                826     110               1.4                            ...
# 4                827     111               6.9                            ...
# ..       ...     ...     ...      ...      ...          ...          ...  ...
# 110             3292   155.8      288      1.6                            ...
# 111             3294   314.7    176.2     12.8                            ...
# 112             3295   519.2     70.6      4.1                            ...
# 113             3297   454.2    192.8     23.9                            ...
# 114             3298   198.3    159.6      7.8                            ...
#
#     MANUAL19                                         RCP_NA_TIP INFO_ENG  \
# 0             저나트륨 무침양념은 된장을 줄이는 대신 두부를 으깨서 넣어 무침 양념양을 늘려 사용...     71.7
# 1                •두반장과 고추기름을 사용해 오이초절임소스를 만들면 새콤달콤한 맛을 낼 수 있어요.     94.4
# 2             저나트륨 잡채에서는 당면, 고기, 각종 채소들을 모두 간을 하지않고 볶고 마지막에 ...    197.7
# 3                                                                   77.7
# 4                                                                  250.4
# ..       ...                                                ...      ...
# 110           •칼륨 함량이 높은 토마토는 나트륨 배출에 도움을 줘요.\n•멸치 육수로 간을 맞추...     36.2
# 111           •칼륨 함량이 높은 천도복숭아는 나트륨 배출에 도움을 주고, 천도복숭아의 단맛으로 ...    102.7
# 112           •미역 줄기를 물에 담그고, 게맛살을 데쳐 나트륨 함량을 줄였어요.\n•양파를 이용...    128.2
# 113           •칼륨 함량이 높은 토마토는 나트륨 배출에 도움을 줘요.\n•미나리를 사용하여 재료...    216.9
# 114                                •플레인 요거트를 이용하여 첨가당 사용을 줄였어요.     88.9
#
#     MANUAL17 MANUAL18           RCP_NM MANUAL15 MANUAL16 MANUAL13 MANUAL14
# 0                               얼갈이 무침
# 1                                오이초절임
# 2                                   잡채
# 3                      참기름 드레싱의 즉석 샐러드
# 4                                고추 장떡
# ..       ...      ...              ...      ...      ...      ...      ...
# 110                            양파토마토스튜
# 111                          황금팽이 비빔국수
# 112                           맛살 미역줄기전
# 113                      해산물샐러드와 미나리소스
# 114                       매운요거트 토마토샐러드
#
# [115 rows x 55 columns]

# %%
#df = df.sort_index(axis=1)
df.sample(5)
# Out:
#                                         RCP_PARTS_DTLS RCP_WAY2 MANUAL_IMG20  \
# 672  두부(8g), 생새우(45g), 팽이버섯(3g), 당근(3g), 깻잎(1g), 파프...       찌기
# 990  고구마(50g), 바나나(17g), 달걀(1개),\n크림치즈(10g), 우유(20g...       기타
# 721  소고기(양지) 3g, 무 20g, 알토란 30g, 대파 15g, 느타리버섯 10g,...      끓이기
# 752  버터 2g, 마늘 1g, 양파 10g, 샐러리 5g, 생강 1g, 닭육수 100g,...      끓이기
# 667  오이 30g, 무 50g, 홍고추 10g, 파프리카 20g, 당근 20g, 미나리 ...       기타
#
#     MANUAL20 RCP_SEQ INFO_NA INFO_WGT INFO_PRO MANUAL_IMG13 MANUAL_IMG14  ...  \
# 672             3213   129.2      165      6.7                            ...
# 990             1097    24.7              11.5                            ...
# 721             3001  675.68      297     7.57                            ...
# 752              935      46               3.1                            ...
# 667             2980   30.88       55     0.34                            ...
#
#     MANUAL19                                         RCP_NA_TIP INFO_ENG  \
# 672           양파장아찌를 곁들여 먹도록 해 따로 간을 하지 않아도 맛있는 애호박순대를 먹을 수 ...    165.4
# 990                 고구마와 바나나로 무스를 만들어 설탕이 없어도 달콤한 무스를 만들 수 있어요.    211.2
# 721                        들깻가루를 이용해 소금을 사용하지 않고 깊은 맛을 낼 수 있어요.   146.42
# 752                                       라임주스는 기호에 따라 생략해도 된다.      102
# 667                          재료를 소금에 절이지 않고 얇게 잘라 나트륨 첨가를 줄였어요.    13.46
#
#     MANUAL17 MANUAL18       RCP_NM MANUAL15 MANUAL16 MANUAL13 MANUAL14
# 672                         애호박 순대
# 990                     고구마 바나나 무스
# 721                    소고기 들깨 알토란탕
# 752                         단호박 스프
# 667                      비타 오이 물김치
#
# [5 rows x 55 columns]

# %%
url = 'https://openapi.foodsafetykorea.go.kr/api/32cb3ef9d10d40e3ad9d/C002/json/1/2' #미친 몇개있는거야? - 천만개는 아니네 ㅋㅋㅋ
response = urlopen(url)
json_api = response.read().decode("utf-8")
json_file = json.loads(json_api)
data_list = json_file['C002']['row']
df = df.append(json_normalize(data_list), ignore_index=True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       4 json_file = json.loads(json_api)
#       5 data_list = json_file['C002']['row']
# ----> 6 df = df.append(json_normalize(data_list), ignore_index=True)
#       7 df
#
# NameError: name 'df' is not defined

# %%
json_file
# Out:
# {'C002': {'total_count': '0',
#   'RESULT': {'MSG': '해당하는 데이터가 없습니다.', 'CODE': 'INFO-200'}}}

# %%
data_list = json_file['C002']['row']
df = df.append(json_normalize(data_list), ignore_index=True)
df
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_32096\3818310277.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = df.append(json_normalize(data_list), ignore_index=True)
#   PRDLST_REPORT_NO   PRMS_DT      LCNS_NO                     PRDLST_NM  \
# 0    2011001517149  20141215  20110015171  GLOBE ULTRA DRY(글로브 울트라 드라이)
#
#       BSSH_NM PRDLST_DCNM                                         RAWMTRL_NM
# 0  하이트진로㈜강원공장          맥주  정제수,글루코아밀라아제,알파아밀라아제,효소제(베타글루카나아제),산도조절제(황산칼슘)...

# %%
# Out:
# 'https://openapi.foodsafetykorea.go.kr/api/32cb3ef9d10d40e3ad9d/C002/xml/500000/500001'

# %%
#2023sus 1/4
df = pd.DataFrame()  # Create an empty DataFrame to store the results
df1 = pd.DataFrame() 
for page in range(1, 2):  # Iterate over all 24126 items (100 items per page, so 242 pages)
    url = f"https://api.odcloud.kr/api/3040719/v1/uddi:d8b66ec2-ab19-47c3-bd6e-883c961885f5?page={page}&perPage=100&returnType=JSON&serviceKey=SDqWmmlSMlsBobBnB0DwlV9IVwFkxNwn42%2BKrK%2F5WMV0AxecYPKMJ2tAurfLvCGOt2hvyBLvi9oG7R%2Bn%2FG4ZUA%3D%3D"
    response = urlopen(url)
    json_api = response.read().decode("utf-8")
    json_file = json.loads(json_api)
    json_file
    # data_list = json_file['data']
#     df = df.append(json_normalize(data_list), ignore_index=True)
#     df1 = df1.append(json_normalize(data_list), ignore_index=True)
# # df_sorted = df.sort_values('접수일', ascending=True)
# # df_sorted
# df1.to_csv('data/소보원데이터/알레르기_2023Q1.csv', index=False, encoding='utf-8-sig')
# df1.to_csv('data/소보원데이터/알레르기_2023Q1_backup.csv', index=False, encoding='utf-8')

# %%
json_file
# Out:
# {'currentCount': 100,
#  'data': [{'발생일자': '2022-12-21',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '어깨(쇄골 포함)',
#    '위해자성별': '남자',
#    '위해자연령': 69,
#    '위해증상(소분류)': '탈구',
#    '위험및위해원인 소분류': '추락',
#    '접수번호': 2023000001,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '스포츠 및 취미용품',
#    '품목소분류': '일반자전거',
#    '품목중분류': '자전거'},
#   {'발생일자': '2022-12-21',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '발목',
#    '위해자성별': '남자',
#    '위해자연령': 12,
#    '위해증상(소분류)': '염좌',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000002,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '스포츠 및 취미용품',
#    '품목소분류': '어린이자전거',
#    '품목중분류': '자전거'},
#   {'발생일자': '2022-12-13',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '발목',
#    '위해자성별': '여자',
#    '위해자연령': 59,
#    '위해증상(소분류)': '타박상',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000005,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '스포츠 및 취미용품',
#    '품목소분류': '일반자전거',
#    '품목중분류': '자전거'},
#   {'발생일자': '2022-12-12',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '무릎',
#    '위해자성별': '남자',
#    '위해자연령': 11,
#    '위해증상(소분류)': '열상(찢어짐)',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000006,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '스포츠 및 취미용품',
#    '품목소분류': '어린이자전거',
#    '품목중분류': '자전거'},
#   {'발생일자': '2022-12-12',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '눈 및 눈주변(눈썹 및 눈꺼풀)',
#    '위해자성별': '여자',
#    '위해자연령': 74,
#    '위해증상(소분류)': '열상(찢어짐)',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000007,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '스포츠 및 취미용품',
#    '품목소분류': '기타 자전거',
#    '품목중분류': '자전거'},
#   {'발생일자': '2022-12-11',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '흉부',
#    '위해자성별': '남자',
#    '위해자연령': 46,
#    '위해증상(소분류)': '타박상',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000008,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '스포츠 및 취미용품',
#    '품목소분류': '일반자전거',
#    '품목중분류': '자전거'},
#   {'발생일자': '2022-12-11',
#    '발생장소': '상세불명의 자연',
#    '위해부위 소분류': '무릎',
#    '위해자성별': '남자',
#    '위해자연령': 61,
#    '위해증상(소분류)': '찰과상',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000009,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '스포츠 및 취미용품',
#    '품목소분류': '일반자전거',
#    '품목중분류': '자전거'},
#   {'발생일자': '2022-12-24',
#    '발생장소': '일반도로',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000034,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-02',
#    '발생장소': '아파트',
#    '위해부위 소분류': '턱',
#    '위해자성별': '여자',
#    '위해자연령': 5,
#    '위해증상(소분류)': '열상(찢어짐)',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000035,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '건축/인테리어 자재 및 작업공구',
#    '품목소분류': '목재마루재',
#    '품목중분류': '천장재 및 바닥재'},
#   {'발생일자': '2022-12-02',
#    '발생장소': '아파트',
#    '위해부위 소분류': '머리 및 뇌(뇌막)',
#    '위해자성별': '남자',
#    '위해자연령': 0,
#    '위해증상(소분류)': '뇌진탕',
#    '위험및위해원인 소분류': '추락',
#    '접수번호': 2023000036,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가구 및 가구설비',
#    '품목소분류': '유아용 침대',
#    '품목중분류': '유아용 가구'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000053,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내승용자-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-09-13',
#    '발생장소': '아파트',
#    '위해부위 소분류': '전신 손상',
#    '위해자성별': '여자',
#    '위해자연령': 40,
#    '위해증상(소분류)': '피부염 또는 피부발진',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000054,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가공식품',
#    '품목소분류': '기타 조리식품',
#    '품목중분류': '기타식품-기타 조리식품'},
#   {'발생일자': '2022-12-02',
#    '발생장소': '아파트',
#    '위해부위 소분류': '전신 손상',
#    '위해자성별': '여자',
#    '위해자연령': 1,
#    '위해증상(소분류)': '두드러기',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000012,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '축산·수산물 식품',
#    '품목소분류': '달걀',
#    '품목중분류': '축산물-유란류'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000024,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '수입승용차-대형',
#    '품목중분류': '수입 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-02',
#    '발생장소': '아파트',
#    '위해부위 소분류': '신체내부-소화계통(식도,위장,대장 등)',
#    '위해자성별': '남자',
#    '위해자연령': 8,
#    '위해증상(소분류)': '소화기계통 장기손상 및 통증',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000025,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가공식품',
#    '품목소분류': '우유류',
#    '품목중분류': '유가공품-일반'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000026,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내승용자-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-01',
#    '발생장소': '카페 및 음식점',
#    '위해부위 소분류': '신체내부-소화계통(식도,위장,대장 등)',
#    '위해자성별': '남자',
#    '위해자연령': 28,
#    '위해증상(소분류)': '소화기계통 장기손상 및 통증',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000027,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가공식품',
#    '품목소분류': '수산물',
#    '품목중분류': '외식-기타'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000028,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내승용자-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-01',
#    '발생장소': '다세대주택',
#    '위해부위 소분류': '신체내부-소화계통(식도,위장,대장 등)',
#    '위해자성별': '남자',
#    '위해자연령': 20,
#    '위해증상(소분류)': '소화기계통 장기손상 및 통증',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000029,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가공식품',
#    '품목소분류': '치킨',
#    '품목중분류': '외식-배달음식'},
#   {'발생일자': '2022-12-26',
#    '발생장소': '상세불명의 주택',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '여자',
#    '위해자연령': 39,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '파열·파손·꺾여짐',
#    '접수번호': 2023000030,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가전제품 및 정보통신기기',
#    '품목소분류': '가습기',
#    '품목중분류': '냉난방 및 계절가전'},
#   {'발생일자': '2022-12-02',
#    '발생장소': '다세대주택',
#    '위해부위 소분류': '팔(아래부분, 팔꿈치 및 손목 제외)',
#    '위해자성별': '여자',
#    '위해자연령': 79,
#    '위해증상(소분류)': '골절',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000033,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '건축/인테리어 자재 및 작업공구',
#    '품목소분류': '석재 또는 타일바닥재',
#    '품목중분류': '천장재 및 바닥재'},
#   {'발생일자': '2022-11-28',
#    '발생장소': '상세불명의 상업시설',
#    '위해부위 소분류': '눈 및 눈주변(눈썹 및 눈꺼풀)',
#    '위해자성별': '여자',
#    '위해자연령': 59,
#    '위해증상(소분류)': '열상(찢어짐)',
#    '위험및위해원인 소분류': '부딪힘',
#    '접수번호': 2023000037,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '건축/인테리어 자재 및 작업공구',
#    '품목소분류': '유리문',
#    '품목중분류': '문'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000038,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '승합차-중형',
#    '품목중분류': '승합자동차(11인승 이상)'},
#   {'발생일자': '2022-12-15',
#    '발생장소': '상세불명의 주택',
#    '위해부위 소분류': '등',
#    '위해자성별': None,
#    '위해자연령': None,
#    '위해증상(소분류)': '화상-뜨거운 액체나 증기로 인한',
#    '위험및위해원인 소분류': '폭발',
#    '접수번호': 2023000039,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가전제품 및 정보통신기기',
#    '품목소분류': '가습기',
#    '품목중분류': '냉난방 및 계절가전'},
#   {'발생일자': '2022-11-27',
#    '발생장소': '대형/복합쇼핑몰',
#    '위해부위 소분류': '머리 및 뇌(뇌막)',
#    '위해자성별': '남자',
#    '위해자연령': 2,
#    '위해증상(소분류)': '뇌진탕',
#    '위험및위해원인 소분류': '추락',
#    '접수번호': 2023000040,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가구 및 가구설비',
#    '품목소분류': '쇼핑카트',
#    '품목중분류': '상품진열 및 매장용 가구'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000043,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '수입 승용차-대형',
#    '품목중분류': '수입 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-09-12',
#    '발생장소': '아파트',
#    '위해부위 소분류': '머리 및 뇌(뇌막)',
#    '위해자성별': '여자',
#    '위해자연령': 3,
#    '위해증상(소분류)': '뇌진탕',
#    '위험및위해원인 소분류': '추락',
#    '접수번호': 2023000051,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가구 및 가구설비',
#    '품목소분류': '유아용 책상',
#    '품목중분류': '유아용 가구'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000052,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '승합차-중형',
#    '품목중분류': '승합자동차(11인승 이상)'},
#   {'발생일자': '2022-09-04',
#    '발생장소': '아파트',
#    '위해부위 소분류': '팔(윗부분)',
#    '위해자성별': '여자',
#    '위해자연령': 85,
#    '위해증상(소분류)': '골절',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000055,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '건축/인테리어 자재 및 작업공구',
#    '품목소분류': '석재 또는 타일바닥재',
#    '품목중분류': '천장재 및 바닥재'},
#   {'발생일자': '2022-12-01',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000106,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가공식품',
#    '품목소분류': '소시지',
#    '품목중분류': '축산물가공품-식육'},
#   {'발생일자': '2022-12-16',
#    '발생장소': '상세불명의 주택',
#    '위해부위 소분류': '위해부위 확인불가',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '화상-열에 의한',
#    '위험및위해원인 소분류': '고온물질',
#    '접수번호': 2023000112,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '의약(외)품 및 의료용구',
#    '품목소분류': '기타 의료용구',
#    '품목중분류': '의료용구'},
#   {'발생일자': '2022-12-01',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000113,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-중형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-11-29',
#    '발생장소': '아파트',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '여자',
#    '위해자연령': 39,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000114,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가전제품 및 정보통신기기',
#    '품목소분류': '가습기',
#    '품목중분류': '냉난방 및 계절가전'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '여자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000115,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-중형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-06-17',
#    '발생장소': '아파트',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '화재',
#    '접수번호': 2023000116,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가전제품 및 정보통신기기',
#    '품목소분류': '가정용 김치냉장고',
#    '품목중분류': '주방 가전'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000121,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '수입 승용차-중형',
#    '품목중분류': '수입 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-14',
#    '발생장소': '세차장',
#    '위해부위 소분류': '위해부위 확인불가',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '위해증상 확인불가',
#    '위험및위해원인 소분류': '조작·사용성 불량',
#    '접수번호': 2023000122,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '건물, 시설 및 서비스',
#    '품목소분류': '세차장 및 세차서비스',
#    '품목중분류': '기타 상업시설 및 서비스'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000123,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-중형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-01',
#    '발생장소': '상세불명의 주택',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '여자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000124,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가전제품 및 정보통신기기',
#    '품목소분류': '가정용 세탁기',
#    '품목중분류': '이미용 및 생활가전'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000125,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '수입 승용차-대형',
#    '품목중분류': '수입 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-09-08',
#    '발생장소': '아파트',
#    '위해부위 소분류': '입술, 혀',
#    '위해자성별': '남자',
#    '위해자연령': 0,
#    '위해증상(소분류)': '부종 또는 피부감각장애',
#    '위험및위해원인 소분류': '추락',
#    '접수번호': 2023000126,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '생활용품',
#    '품목소분류': '기타 침구 및 매트',
#    '품목중분류': '침구 및 매트'},
#   {'발생일자': '2022-12-22',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': 66,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 위험 및 위해내용',
#    '접수번호': 2023000141,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '완구 및 게임용품',
#    '품목소분류': '기타 완구',
#    '품목중분류': '완구'},
#   {'발생일자': '2022-12-22',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': 69,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000144,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가공식품',
#    '품목소분류': '시리얼',
#    '품목중분류': '식물가공식품-곡류'},
#   {'발생일자': '2022-12-21',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000145,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '수입 승용차-중형',
#    '품목중분류': '수입 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-09-08',
#    '발생장소': '일반도로',
#    '위해부위 소분류': '둔부',
#    '위해자성별': '여자',
#    '위해자연령': 17,
#    '위해증상(소분류)': '염좌',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000146,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '전동휠',
#    '품목중분류': '기타 승용물'},
#   {'발생일자': '2022-11-27',
#    '발생장소': '아파트',
#    '위해부위 소분류': '전신 손상',
#    '위해자성별': '남자',
#    '위해자연령': 2,
#    '위해증상(소분류)': '두드러기',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000147,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가공식품',
#    '품목소분류': '기타 건강식품',
#    '품목중분류': '건강식품-기타'},
#   {'발생일자': '2022-12-21',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000149,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-중형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-22',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': 62,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 위험 및 위해내용',
#    '접수번호': 2023000151,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '완구 및 게임용품',
#    '품목소분류': '기타 완구',
#    '품목중분류': '완구'},
#   {'발생일자': '2022-12-01',
#    '발생장소': '아파트',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': 49,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '이물질(가스 및 기체류)',
#    '접수번호': 2023000152,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가전제품 및 정보통신기기',
#    '품목소분류': '가정용 전기밥솥',
#    '품목중분류': '주방 가전'},
#   {'발생일자': '2022-12-18',
#    '발생장소': '카페 및 음식점',
#    '위해부위 소분류': '신체내부-소화계통(식도,위장,대장 등)',
#    '위해자성별': '여자',
#    '위해자연령': 29,
#    '위해증상(소분류)': '소화기계통 장기손상 및 통증',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000153,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가공식품',
#    '품목소분류': '고기류',
#    '품목중분류': '외식-한식'},
#   {'발생일자': '2022-12-30',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': None,
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000010,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가공식품',
#    '품목소분류': '스낵',
#    '품목중분류': '빵(떡) 및 과자류-과자'},
#   {'발생일자': '2022-12-10',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '둔부',
#    '위해자성별': '남자',
#    '위해자연령': 14,
#    '위해증상(소분류)': '타박상',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000011,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '스포츠 및 취미용품',
#    '품목소분류': '어린이자전거',
#    '품목중분류': '자전거'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000032,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내승용자-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2023-01-02',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 위험 및 위해내용',
#    '접수번호': 2023000046,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '화재, 안전 및 보안 장비',
#    '품목소분류': '소화기',
#    '품목중분류': '소방장비'},
#   {'발생일자': '2022-11-28',
#    '발생장소': '아파트',
#    '위해부위 소분류': '눈 및 눈주변(눈썹 및 눈꺼풀)',
#    '위해자성별': '남자',
#    '위해자연령': 1,
#    '위해증상(소분류)': '열상(찢어짐)',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000047,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '완구 및 게임용품',
#    '품목소분류': '승용완구',
#    '품목중분류': '완구'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000048,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내승용자-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-09-10',
#    '발생장소': '아파트',
#    '위해부위 소분류': '신체내부-소화계통(식도,위장,대장 등)',
#    '위해자성별': '여자',
#    '위해자연령': 51,
#    '위해증상(소분류)': '소화기계통 장기손상 및 통증',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000061,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '축산·수산물 식품',
#    '품목소분류': '게',
#    '품목중분류': '수산물-갑각류'},
#   {'발생일자': '2022-09-10',
#    '발생장소': '아파트',
#    '위해부위 소분류': '턱',
#    '위해자성별': '남자',
#    '위해자연령': 5,
#    '위해증상(소분류)': '열상(찢어짐)',
#    '위험및위해원인 소분류': '추락',
#    '접수번호': 2023000062,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '스포츠 및 취미용품',
#    '품목소분류': '놀이터용 기어오르기시설',
#    '품목중분류': '놀이터 장비 및 용품'},
#   {'발생일자': '2022-11-25',
#    '발생장소': '상세불명의 여가, 문화 및 놀이시설',
#    '위해부위 소분류': '팔(아래부분, 팔꿈치 및 손목 제외)',
#    '위해자성별': '여자',
#    '위해자연령': 7,
#    '위해증상(소분류)': '골절',
#    '위험및위해원인 소분류': '추락',
#    '접수번호': 2023000063,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '스포츠 및 취미용품',
#    '품목소분류': '기타 놀이터 장비 및 용품',
#    '품목중분류': '놀이터 장비 및 용품'},
#   {'발생일자': '2022-09-10',
#    '발생장소': '아파트',
#    '위해부위 소분류': '코',
#    '위해자성별': '여자',
#    '위해자연령': 2,
#    '위해증상(소분류)': '체내 위험 이물질',
#    '위험및위해원인 소분류': '이물질(기타)',
#    '접수번호': 2023000064,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '식물 식품',
#    '품목소분류': '땅콩',
#    '품목중분류': '곡류-견과종실류'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000065,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내승용자-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-11-19',
#    '발생장소': '상세불명의 주택',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000067,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가전제품 및 정보통신기기',
#    '품목소분류': '가정용 세탁기',
#    '품목중분류': '이미용 및 생활가전'},
#   {'발생일자': '2022-11-01',
#    '발생장소': '상세불명의 주택',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '여자',
#    '위해자연령': 49,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '파열·파손·꺾여짐',
#    '접수번호': 2023000068,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '의약(외)품 및 의료용구',
#    '품목소분류': '전기마사지기',
#    '품목중분류': '의료용구'},
#   {'발생일자': '2022-12-22',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': 68,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '식품 섭취에 의한 위험 및 위해',
#    '접수번호': 2023000073,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가공식품',
#    '품목소분류': '기타 영양보충제품',
#    '품목중분류': '건강식품-영양 보충제품'},
#   {'발생일자': '2022-11-26',
#    '발생장소': '피부관리실',
#    '위해부위 소분류': '흉부',
#    '위해자성별': '여자',
#    '위해자연령': 59,
#    '위해증상(소분류)': '골절',
#    '위험및위해원인 소분류': '기타 물리적 충격',
#    '접수번호': 2023000075,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '건물, 시설 및 서비스',
#    '품목소분류': '피부관리실 및 피부관리서비스',
#    '품목중분류': '기타 상업시설 및 서비스'},
#   {'발생일자': '2022-10-23',
#    '발생장소': '카페 및 음식점',
#    '위해부위 소분류': '신체내부-소화계통(식도,위장,대장 등)',
#    '위해자성별': '여자',
#    '위해자연령': 39,
#    '위해증상(소분류)': '체내 위험 이물질',
#    '위험및위해원인 소분류': '이물질(기타)',
#    '접수번호': 2023000076,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가공식품',
#    '품목소분류': '초밥',
#    '품목중분류': '외식-일식'},
#   {'발생일자': '2022-12-21',
#    '발생장소': '아파트',
#    '위해부위 소분류': '등',
#    '위해자성별': '남자',
#    '위해자연령': 30,
#    '위해증상(소분류)': '피부염 또는 피부발진',
#    '위험및위해원인 소분류': '피부접촉에 의한 위험 및 위해',
#    '접수번호': 2023000081,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '스포츠 및 취미용품',
#    '품목소분류': 'WET수트',
#    '품목중분류': '수중 스포츠 장비'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '여자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000085,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-중형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000086,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-중형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '대형/복합쇼핑몰',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000087,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내승용자-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '연료·액체 누수 등',
#    '접수번호': 2023000088,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-중형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-09-09',
#    '발생장소': '아파트',
#    '위해부위 소분류': '신체내부-소화계통(식도,위장,대장 등)',
#    '위해자성별': '남자',
#    '위해자연령': 1,
#    '위해증상(소분류)': '체내 위험 이물질',
#    '위험및위해원인 소분류': '약물 오·남용',
#    '접수번호': 2023000089,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '의약(외)품 및 의료용구',
#    '품목소분류': '외피용약',
#    '품목중분류': '의약품'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '여자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000090,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '여자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000092,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '승합차-중형',
#    '품목중분류': '승합자동차(11인승 이상)'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000093,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-중형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-09-11',
#    '발생장소': '상세불명의 주택',
#    '위해부위 소분류': '손목',
#    '위해자성별': '남자',
#    '위해자연령': 59,
#    '위해증상(소분류)': '화상-열에 의한',
#    '위험및위해원인 소분류': '폭발',
#    '접수번호': 2023000099,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가전제품 및 정보통신기기',
#    '품목소분류': '가정용 모발건조기(헤어드라이어)',
#    '품목중분류': '이미용 및 생활가전'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000111,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내승용자-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000117,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000118,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내승용자-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000119,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-중형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-09-09',
#    '발생장소': '아파트',
#    '위해부위 소분류': '생식기 주변 및 회음부',
#    '위해자성별': '여자',
#    '위해자연령': 52,
#    '위해증상(소분류)': '체내 위험 이물질',
#    '위험및위해원인 소분류': '이물질(기타)',
#    '접수번호': 2023000128,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '의약(외)품 및 의료용구',
#    '품목소분류': '약포장',
#    '품목중분류': '약포장'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000129,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '수입 승용차-중형',
#    '품목중분류': '수입 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000130,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내승용자-소형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-09-14',
#    '발생장소': '아파트',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': 39,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000133,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가구 및 가구설비',
#    '품목소분류': '침대부품 및 액세서리',
#    '품목중분류': '침실가구'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000134,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내승용자-대형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-20',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기능고장',
#    '접수번호': 2023000136,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '수입 승용차-대형',
#    '품목중분류': '수입 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-21',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000138,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '승합차-중형',
#    '품목중분류': '승합자동차(11인승 이상)'},
#   {'발생일자': '2022-12-21',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000140,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-중형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-22',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': 64,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 위험 및 위해내용',
#    '접수번호': 2023000142,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '완구 및 게임용품',
#    '품목소분류': '장난감 자동차',
#    '품목중분류': '완구'},
#   {'발생일자': '2022-12-21',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000143,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-중형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '기타 불량 및 고장',
#    '접수번호': 2023000031,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '국내 승용차-소형',
#    '품목중분류': '국내 승용자동차(10인승 이하)'},
#   {'발생일자': '2022-12-19',
#    '발생장소': '상세불명의 장소',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': None,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '연료·액체 누수 등',
#    '접수번호': 2023000049,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '수입 승용차-대형',
#    '품목중분류': '수입 승용자동차(10인승 이하)'},
#   {'발생일자': None,
#    '발생장소': '상세불명의 주택',
#    '위해부위 소분류': '손가락',
#    '위해자성별': '남자',
#    '위해자연령': 44,
#    '위해증상(소분류)': '화상-뜨거운 액체나 증기로 인한',
#    '위험및위해원인 소분류': '고온물질',
#    '접수번호': 2023000050,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가전제품 및 정보통신기기',
#    '품목소분류': '가습기',
#    '품목중분류': '냉난방 및 계절가전'},
#   {'발생일자': '2022-09-12',
#    '발생장소': '상세불명의 도로 및 인도',
#    '위해부위 소분류': '턱',
#    '위해자성별': '남자',
#    '위해자연령': 17,
#    '위해증상(소분류)': '열상(찢어짐)',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000056,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '자동차 및 관련 용품',
#    '품목소분류': '전동휠',
#    '품목중분류': '기타 승용물'},
#   {'발생일자': '2022-09-10',
#    '발생장소': '아파트',
#    '위해부위 소분류': '흉부',
#    '위해자성별': '여자',
#    '위해자연령': 66,
#    '위해증상(소분류)': '골절',
#    '위험및위해원인 소분류': '미끄러짐·넘어짐',
#    '접수번호': 2023000058,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '건축/인테리어 자재 및 작업공구',
#    '품목소분류': '석재 또는 타일바닥재',
#    '품목중분류': '천장재 및 바닥재'},
#   {'발생일자': '2022-09-10',
#    '발생장소': '아파트',
#    '위해부위 소분류': '안구',
#    '위해자성별': '여자',
#    '위해자연령': 48,
#    '위해증상(소분류)': '결막염 또는 안구손상',
#    '위험및위해원인 소분류': '이물질(액체류)',
#    '접수번호': 2023000059,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '화장품 및 화장용품',
#    '품목소분류': '네일폴리시·네일에나멜 리무버',
#    '품목중분류': '손발톱용 화장품'},
#   {'발생일자': '2022-09-10',
#    '발생장소': '아파트',
#    '위해부위 소분류': '코',
#    '위해자성별': '여자',
#    '위해자연령': 7,
#    '위해증상(소분류)': '체내 위험 이물질',
#    '위험및위해원인 소분류': '이물질(기타)',
#    '접수번호': 2023000060,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '완구 및 게임용품',
#    '품목소분류': '구슬',
#    '품목중분류': '완구'},
#   {'발생일자': '2022-09-10',
#    '발생장소': '아파트',
#    '위해부위 소분류': '입술, 혀',
#    '위해자성별': '남자',
#    '위해자연령': 4,
#    '위해증상(소분류)': '타박상',
#    '위험및위해원인 소분류': '추락',
#    '접수번호': 2023000066,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가구 및 가구설비',
#    '품목소분류': '침대',
#    '품목중분류': '침실가구'},
#   {'발생일자': '2022-08-01',
#    '발생장소': '상세불명의 주택',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '남자',
#    '위해자연령': 79,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '화재',
#    '접수번호': 2023000069,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '가전제품 및 정보통신기기',
#    '품목소분류': '가정용 김치냉장고',
#    '품목중분류': '주방 가전'},
#   {'발생일자': '2022-10-20',
#    '발생장소': '아파트',
#    '위해부위 소분류': '해당없음',
#    '위해자성별': '여자',
#    '위해자연령': 49,
#    '위해증상(소분류)': '해당없음',
#    '위험및위해원인 소분류': '부품탈락',
#    '접수번호': 2023000070,
#    '접수일': '2023-01-02',
#    '치료기간': '해당없음',
#    '품목대분류': '생활용품',
#    '품목소분류': '칫솔 및 구강세척용품(치실, 치간칫솔 등)',
#    '품목중분류': '가정용 욕실용품'}],
#  'matchCount': 24126,
#  'page': 1,
#  'perPage': 100,
#  'totalCount': 24126}

# %%
#2022 4/4
df1 = pd.DataFrame() 
for page in range(1, 127):  # Iterate over all 24126 items (100 items per page, so 242 pages)
    url = f"https://api.odcloud.kr/api/3040719/v1/uddi:ae040a91-52c0-4d06-9b8c-e38a849bb4c0?page={page}&perPage=100&serviceKey=SDqWmmlSMlsBobBnB0DwlV9IVwFkxNwn42%2BKrK%2F5WMV0AxecYPKMJ2tAurfLvCGOt2hvyBLvi9oG7R%2Bn%2FG4ZUA%3D%3D"
    response = urlopen(url)
    json_api = response.read().decode("utf-8")
    json_file = json.loads(json_api)
    data_list = json_file['data']
    df = df.append(json_normalize(data_list), ignore_index=True)
    df1 = df1.append(json_normalize(data_list), ignore_index=True)
#12508
df1.tail()
length = length+len(df1)
print(length,len(df1))
df1.to_csv('data/소보원데이터/알레르기_2022Q4.csv', index=False, encoding='utf-8-sig')
df1.to_csv('data/소보원데이터/알레르기_2022Q4_backup.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\1996006333.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = df.append(json_normalize(data_list), ignore_index=True)
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\1996006333.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df1 = df1.append(json_normalize(data_list), ignore_index=True)
# 189225 12508

# %%
#2022 3/4
df1 = pd.DataFrame()  # Create an empty DataFrame to store the results
for page in range(1, 222):  # Iterate over all 24126 items (100 items per page, so 242 pages)
    url = f"https://api.odcloud.kr/api/3040719/v1/uddi:6485a24f-6f78-4f06-a093-da7bb91768cf?page={page}&perPage=100&serviceKey=SDqWmmlSMlsBobBnB0DwlV9IVwFkxNwn42%2BKrK%2F5WMV0AxecYPKMJ2tAurfLvCGOt2hvyBLvi9oG7R%2Bn%2FG4ZUA%3D%3D"
    response = urlopen(url)
    json_api = response.read().decode("utf-8")
    json_file = json.loads(json_api)
    data_list = json_file['data']
    df = df.append(json_normalize(data_list), ignore_index=True)
    df1 = df1.append(json_normalize(data_list), ignore_index=True)

df1.tail()
#22018
length = length+len(df1)
print(length,len(df1))
df1.to_csv('data/소보원데이터/알레르기_2022Q3.csv', index=False, encoding='utf-8-sig')
df1.to_csv('data/소보원데이터/알레르기_2022Q3_backup.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\2974269269.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = df.append(json_normalize(data_list), ignore_index=True)
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\2974269269.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df1 = df1.append(json_normalize(data_list), ignore_index=True)
# 211243 22018

# %%
#2022 2/4
df1 = pd.DataFrame()  # Create an empty DataFrame to store the results
for page in range(1, 229):  # Iterate over all 24126 items (100 items per page, so 242 pages)
    url = f"https://api.odcloud.kr/api/3040719/v1/uddi:8ec97038-5f23-4c15-a24b-ca7b9cc69f8e?page={page}&perPage=100&serviceKey=SDqWmmlSMlsBobBnB0DwlV9IVwFkxNwn42%2BKrK%2F5WMV0AxecYPKMJ2tAurfLvCGOt2hvyBLvi9oG7R%2Bn%2FG4ZUA%3D%3D"
    response = urlopen(url)
    json_api = response.read().decode("utf-8")
    json_file = json.loads(json_api)
    data_list = json_file['data']
    df = df.append(json_normalize(data_list), ignore_index=True)
    df1 = df1.append(json_normalize(data_list), ignore_index=True)
#22716
df1.tail()
length = length+len(df1)
print(length,len(df1))
df1.to_csv('data/소보원데이터/알레르기_2022Q2.csv', index=False, encoding='utf-8-sig')
df1.to_csv('data/소보원데이터/알레르기_2022Q2_backup.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\883949373.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = df.append(json_normalize(data_list), ignore_index=True)
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\883949373.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df1 = df1.append(json_normalize(data_list), ignore_index=True)
# 233959 22716

# %%
#2022 1/4
df1 = pd.DataFrame()  # Create an empty DataFrame to store the results

for page in range(1, 215):  # Iterate over all 24126 items (100 items per page, so 242 pages)
    url = f"https://api.odcloud.kr/api/3040719/v1/uddi:31ac447c-dccd-4db7-998d-edd0136690e7?page={page}&perPage=100&serviceKey=SDqWmmlSMlsBobBnB0DwlV9IVwFkxNwn42%2BKrK%2F5WMV0AxecYPKMJ2tAurfLvCGOt2hvyBLvi9oG7R%2Bn%2FG4ZUA%3D%3D"
    response = urlopen(url)
    json_api = response.read().decode("utf-8")
    json_file = json.loads(json_api)
    data_list = json_file['data']
    df = df.append(json_normalize(data_list), ignore_index=True)
    df1 = df1.append(json_normalize(data_list), ignore_index=True)
#21349
df1.tail()
length = length+len(df1)
print(length,len(df1))
df1.to_csv('data/소보원데이터/알레르기_2022Q1.csv', index=False, encoding='utf-8-sig')
df1.to_csv('data/소보원데이터/알레르기_2022Q1_backup.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\2450305332.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = df.append(json_normalize(data_list), ignore_index=True)
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\2450305332.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df1 = df1.append(json_normalize(data_list), ignore_index=True)
# 255308 21349

# %%
#2021 4/4
df1 = pd.DataFrame()  # Create an empty DataFrame to store the results
#18642
for page in range(1, 188):  # Iterate over all 24126 items (100 items per page, so 242 pages)
    url = f"https://api.odcloud.kr/api/3040719/v1/uddi:06685e15-7202-48e2-8611-abb2e43eb820?page={page}&perPage=100&serviceKey=SDqWmmlSMlsBobBnB0DwlV9IVwFkxNwn42%2BKrK%2F5WMV0AxecYPKMJ2tAurfLvCGOt2hvyBLvi9oG7R%2Bn%2FG4ZUA%3D%3D"
    response = urlopen(url)
    json_api = response.read().decode("utf-8")
    json_file = json.loads(json_api)
    data_list = json_file['data']
    df = df.append(json_normalize(data_list), ignore_index=True)
    df1 = df1.append(json_normalize(data_list), ignore_index=True)
df1.tail()
length = length+len(df1)
print(length,len(df1))
df1.to_csv('data/소보원데이터/알레르기_2021Q4.csv', index=False, encoding='utf-8-sig')
df1.to_csv('data/소보원데이터/알레르기_2021Q4_backup.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\3589748750.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = df.append(json_normalize(data_list), ignore_index=True)
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\3589748750.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df1 = df1.append(json_normalize(data_list), ignore_index=True)
# 273950 18642

# %%
#2021 3/4
df1 = pd.DataFrame()  # Create an empty DataFrame to store the results
#24818
for page in range(1, 250):  # Iterate over all 24126 items (100 items per page, so 242 pages)
    url = f"https://api.odcloud.kr/api/3040719/v1/uddi:93fe0df3-2704-4f3a-9455-d0411d9467a6?page={page}&perPage=100&serviceKey=SDqWmmlSMlsBobBnB0DwlV9IVwFkxNwn42%2BKrK%2F5WMV0AxecYPKMJ2tAurfLvCGOt2hvyBLvi9oG7R%2Bn%2FG4ZUA%3D%3D"
    response = urlopen(url)
    json_api = response.read().decode("utf-8")
    json_file = json.loads(json_api)
    data_list = json_file['data']
    df = df.append(json_normalize(data_list), ignore_index=True)
    df1 = df1.append(json_normalize(data_list), ignore_index=True)
df1.tail()
length = length+len(df1)
print(length,len(df1))
df1.to_csv('data/소보원데이터/알레르기_2021Q3.csv', index=False, encoding='utf-8-sig')
df1.to_csv('data/소보원데이터/알레르기_2021Q3_backup.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\4269925221.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = df.append(json_normalize(data_list), ignore_index=True)
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\4269925221.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df1 = df1.append(json_normalize(data_list), ignore_index=True)
# 298768 24818

# %%
#2021 2/4
df1 = pd.DataFrame()  # Create an empty DataFrame to store the results
#19085 192
for page in range(1, 192):  # Iterate over all 24126 items (100 items per page, so 242 pages)
    url = f"https://api.odcloud.kr/api/3040719/v1/uddi:df00cf82-37cd-4bf1-82e7-b4ab1ce51f19?page={page}&perPage=100&serviceKey=SDqWmmlSMlsBobBnB0DwlV9IVwFkxNwn42%2BKrK%2F5WMV0AxecYPKMJ2tAurfLvCGOt2hvyBLvi9oG7R%2Bn%2FG4ZUA%3D%3D"
    response = urlopen(url)
    json_api = response.read().decode("utf-8")
    json_file = json.loads(json_api)
    data_list = json_file['data']
    df = df.append(json_normalize(data_list), ignore_index=True)
    df1 = df1.append(json_normalize(data_list), ignore_index=True)
df1.tail()
length = length+len(df1)
print(length,len(df1))
df1.to_csv('data/소보원데이터/알레르기_2021Q2.csv', index=False, encoding='utf-8-sig')
df1.to_csv('data/소보원데이터/알레르기_2021Q2_backup.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\1628224593.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = df.append(json_normalize(data_list), ignore_index=True)
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\1628224593.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df1 = df1.append(json_normalize(data_list), ignore_index=True)
# 317853 19085

# %%
#2021 1/4
df1 = pd.DataFrame()  # Create an empty DataFrame to store the results
#11455 116
for page in range(1, 116):  # Iterate over all 24126 items (100 items per page, so 242 pages)
    url = f"https://api.odcloud.kr/api/3040719/v1/uddi:836524d6-0ecb-4084-9230-f656bed7a061?page={page}&perPage=100&serviceKey=SDqWmmlSMlsBobBnB0DwlV9IVwFkxNwn42%2BKrK%2F5WMV0AxecYPKMJ2tAurfLvCGOt2hvyBLvi9oG7R%2Bn%2FG4ZUA%3D%3D"
    response = urlopen(url)
    json_api = response.read().decode("utf-8")
    json_file = json.loads(json_api)
    data_list = json_file['data']
    df = df.append(json_normalize(data_list), ignore_index=True)
    df1 = df1.append(json_normalize(data_list), ignore_index=True)
df1.tail()
length = length+len(df1)
print(length,len(df1))
df1.to_csv('data/소보원데이터/알레르기_2021Q1.csv', index=False, encoding='utf-8-sig')
df1.to_csv('data/소보원데이터/알레르기_2021Q1_backup.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\1200875724.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = df.append(json_normalize(data_list), ignore_index=True)
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_28612\1200875724.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df1 = df1.append(json_normalize(data_list), ignore_index=True)
# 329308 11455

# %%
print(length)
print(len(df))
# Out:
# 176717
# 176717

# %%
df1.to_csv('알레르기_2021-2023Q1.csv', index=False, encoding='utf-8-sig')
df1.to_csv('알레르기_2021-2023Q1_backup.csv', index=False, encoding='utf-8')

# %%
# df = pd.read_csv('data/소보원데이터/알레르기_2021Q1_backup.csv') #원인 불명 (알레르기 분류가 없음)
# df1 = pd.read_csv('data/소보원데이터/알레르기_2021Q2_backup.csv') #원인 불명 (알레르기 분류가 없음)
df2 = pd.read_csv('data/소보원데이터/알레르기_2021Q3_backup.csv')
df3 = pd.read_csv('data/소보원데이터/알레르기_2021Q4_backup.csv')
df4 = pd.read_csv('data/소보원데이터/알레르기_2022Q1_backup.csv')
df5 = pd.read_csv('data/소보원데이터/알레르기_2022Q2_backup.csv')
df6 = pd.read_csv('data/소보원데이터/알레르기_2022Q3_backup.csv')
df7 = pd.read_csv('data/소보원데이터/알레르기_2022Q4_backup.csv')
df8 = pd.read_csv('data/소보원데이터/알레르기_2023Q1_backup.csv')

# %%
df2.drop(columns=['발생일자','발생장소', '접수번호'], axis=1, inplace=True)
df3.drop(columns=['발생일자','발생장소', '접수번호'], axis=1, inplace=True)
df4.drop(columns=['발생일자','발생장소', '접수번호'], axis=1, inplace=True)
df5.drop(columns=['발생일자','발생장소 소분류', '접수번호'], axis=1, inplace=True)
df6.drop(columns=['발생일자','발생장소 소분류', '접수번호'], axis=1, inplace=True)
df7.drop(columns=['발생일자','발생장소', '접수번호'], axis=1, inplace=True)
df8.drop(columns=['발생일자','발생장소', '접수번호'], axis=1, inplace=True)

# %%
df7.rename(columns={'위해증상 (소분류)':'위해증상 소분류'}, inplace=True)
df7.rename(columns={'위험 및 위해원인 소분류':'위험및위해원인 소분류'}, inplace=True)
df8.rename(columns={'위해증상(소분류)':'위해증상 소분류'}, inplace=True)

# %%
df = pd.concat([df2, df3, df4, df5, df6, df7, df8])
df.fillna("알수없음", inplace=True) #성별, 연령
df.isnull().sum()
# Out:
# 위해부위 소분류       0
# 위해자성별          0
# 위해자연령          0
# 위해증상 소분류       0
# 위험및위해원인 소분류    0
# 접수일            0
# 치료기간           0
# 품목대분류          0
# 품목소분류          0
# 품목중분류          0
# dtype: int64

# %%
df = df[df['위해증상 소분류'].str.contains('알레르기', na=False)]
df = df[df['위험및위해원인 소분류'].str.contains('식품', na=False)]

# %%
df['접수일'] = pd.to_datetime(df['접수일']) 
# df['년도'] = df['접수일'].dt.year 
# df['분기'] = df['접수일'].dt.quarter
df['년도_분기'] = df['접수일'].dt.year.astype(str) + '-Q' + df['접수일'].dt.quarter.astype(str)  # '년도_분기' 컬럼을 생성하여 년도와 분기를 문자열로 연결하여 저장합니다.
df.head()
# Out:
#                 위해부위 소분류 위해자성별 위해자연령 위해증상 소분류        위험및위해원인 소분류        접수일  \
# 682                전신 손상    여자  36.0     알레르기  식품 섭취에 의한 위험 및 위해 2021-07-05
# 3331           위해부위 확인불가    여자  알수없음     알레르기  식품 섭취에 의한 위험 및 위해 2021-07-13
# 8192   눈 및 눈주변(눈썹 및 눈꺼풀)    여자  25.0     알레르기  식품 섭취에 의한 위험 및 위해 2021-07-27
# 11129              입술, 혀    여자  44.0     알레르기  식품 섭취에 의한 위험 및 위해 2021-08-06
# 13216              전신 손상    여자  29.0     알레르기  식품 섭취에 의한 위험 및 위해 2021-08-17
#
#        치료기간      품목대분류       품목소분류         품목중분류    년도_분기
# 682    해당없음  축산·수산물 식품          돼지       축산물-포유류  2021-Q3
# 3331   해당없음       가공식품  일반 다이어트 식품  건강식품-다이어트 제품  2021-Q3
# 8192   해당없음  축산·수산물 식품         고등어      수산물-해양어류  2021-Q3
# 11129  해당없음  축산·수산물 식품           소       축산물-포유류  2021-Q3
# 13216  해당없음       가공식품    떡볶이(라볶이)         외식-분식  2021-Q3

# %%
df_groupby = df.groupby("년도_분기")['접수일'].agg(['count'])
df_groupby1 = df.groupby(["년도_분기","품목대분류"]).agg(['count'])
df_groupby1 = df_groupby1['위해부위 소분류']
df_groupby1
# Out:
#                    count
# 년도_분기   품목대분류
# 2021-Q3 가공식품           6
#         식물 식품          1
#         축산·수산물 식품      4
# 2021-Q4 가공식품          15
#         식물 식품          4
#         축산·수산물 식품      2
# 2022-Q1 가공식품          16
#         축산·수산물 식품      1
# 2022-Q2 가공식품          19
#         식물 식품          3
#         축산·수산물 식품      9
# 2022-Q3 가공식품          25
#         식물 식품          4
#         축산·수산물 식품      7
# 2022-Q4 가공식품          16
#         식물 식품          1
#         축산·수산물 식품      5
# 2023-Q1 가공식품          33
#         식물 식품          8
#         축산·수산물 식품      9

# %%
import plotly.express as px
import plotly.graph_objects as go

df_reset = df_groupby.reset_index()
fig = px.line(df_reset, x='년도_분기', y='count', text="count")
fig.update_traces(textposition="top center")
fig.update_layout(
    title = "한국소비자원 소비자 위해 정보: 식품-알레르기 신고 접수건수",
    xaxis_title="년도-분기",
    yaxis_title="신고 건수",
    )
fig.show()

# %%
import plotly.express as px

df_reset1 = df_groupby1.reset_index()
fig = px.bar(df_reset1, x='년도_분기', y='count', color = '품목대분류', barmode='group', text_auto=True)
fig.update_traces(textposition="outside")
fig.update_layout(
    title="위해품목 대분류별 신고 건수 추이",
    xaxis_title="년도-분기",
    yaxis_title="신고 건수",
     legend=dict(
        title="",
        orientation="h",
        yanchor="bottom",
        y=1.07,
        xanchor="center",
        x=0.86
    )
)
fig.show()

# %%
import plotly.express as px
import plotly.graph_objects as go

df_reset = df_groupby.reset_index()
fig1 = px.line(df_reset, x='년도_분기', y='count', text="count")
fig1.update_traces(textposition="top center")
fig1.update_layout(
    title="한국소비자원 소비자 위해 정보: 식품-알레르기 신고 접수건수",
    xaxis_title="년도-분기",
    yaxis_title="신고 건수"
)

df_reset1 = df_groupby1.reset_index()
fig2 = px.bar(df_reset1, x='년도_분기', y='count', color='품목대분류', barmode='group', text_auto=True)
fig2.update_traces(textposition="auto", textfont=dict(size=12), textangle=0)
fig2.update_layout(
    title="위해품목 대분류별 신고 건수 추이",
    xaxis_title="년도-분기",
    yaxis_title="신고 건수",
    
)

# 겹쳐진 그래프 생성
fig_combined = go.Figure()

# Line 그래프를 추가합니다.
for data in fig1.data:
    fig_combined.add_trace(data)

# Bar 그래프를 추가합니다.
for data in fig2.data:
    fig_combined.add_trace(data)

fig_combined.update_layout(
    title=dict(
        text="한국소비자원 소비자 위해 정보: 식품-알레르기 전체/품목대분류별 신고 접수건수",
        x=0.5,
        xanchor="center"
    ),
    xaxis_title="년도-분기",
    yaxis_title="신고 건수",
    legend=dict(
        title="",
        orientation="h",
        yanchor="bottom",
        y=1.01,
        xanchor="center",
        x=0.5)
)

fig_combined.show()
