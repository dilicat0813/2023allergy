# %%
from hanspell import spell_checker
import json
import re

# XML 형식에 맞지 않는 문자 제거

# %%
input = "연육46.90%(미국산/어육,D-소비톨,정백당,산도조절제),대두유 대두:외국산(미국,브라질,파라과이),양파(국내산),혼합제제(타피오카변성전분,말토덱스트린),두류가공품-1,두부,당근,밀가루,전분가공품,고추,소맥전분,유산균배양액혼합분말,정백당,정제염,당면,난백액,두류가공품-2,효모추출물혼합분말,타이미,마늘,함수결정포도당,D-자일로오스,혼합제제(말토덱스트린/트랜스글루타미나아제)/가쓰오분말스프:정제소금(국내산),백설탕,덱스트린,양조간장조미분말S{양조간장(탈지대두:인도산),덱스트린,멸치액젓(태국산),정제소금,효모추출물},에이치브이피-에이지(중국산/식물성 가수분해단백물,덱스트린),고농축간장분말,맛베이스-3,무추출물분말,치킨스톡P,에이치브이피-에이치알,알파콘씨,가쓰오부시분말1.85%{가다랑어100%(인도네시아산)},건대파후레이크,정제팜유,5`-리보뉴클레오티드이나트륨,멸치가루,양파분말,청양고추 농축분말,효모추출물,무수구연산,호박산이나트륨,흑후추분말,올레오레진캪시컴"

#input ="밀가루(밀/미국산,캐나다산)43.1%,곡류가공품1[대두분(대두/중국산)40%,소맥분(밀/수입산)29%,해바라기씨20%,식염,곡류가공품,몰트분말1%,보리분말1%]4.3%,곡류가공품2[대두분(대두/중국산)19%,옥수수분말(옥수수/수입산)15%,소맥분(밀)12.7%,탄산칼슘(분산제),호밀분10%,보리7%,아마씨5.3%,몰트3%, 흑미3%,쌀3%,수수2%,조1%]4.3%,마아가린,백설탕,곡류가공품3,생효모,탈지분유,정제소금,혼합제제1(소맥분,스테아릴젖산나트륨,비타민C,효소제제),카라멜,혼합제제2(산도조절제,분말포도당,유화제,영양강화제),이스트후드(기타가공품)","밀,대두,우유함유"
try:
    input = input.replace("&","").replace("*","").replace("{","").replace("}","").replace("/","").replace("[","").replace("]","").replace("-","")#.replace("("," ").replace(")"," ")
    result = spell_checker.check(input) 
    print(result)
except:
    print(input)
# Out:
# 연육46.90%(미국산어육,D소비톨,정백당,산도조절제),대두유 대두:외국산(미국,브라질,파라과이),양파(국내산),혼합제제(타피오카변성전분,말토덱스트린),두류가공품1,두부,당근,밀가루,전분가공품,고추,소맥전분,유산균배양액혼합분말,정백당,정제염,당면,난백액,두류가공품2,효모추출물혼합분말,타이미,마늘,함수결정포도당,D자일로오스,혼합제제(말토덱스트린트랜스글루타미나아제)가쓰오분말스프:정제소금(국내산),백설탕,덱스트린,양조간장조미분말S양조간장(탈지대두:인도산),덱스트린,멸치액젓(태국산),정제소금,효모추출물,에이치브이피에이지(중국산식물성 가수분해단백물,덱스트린),고농축간장분말,맛베이스3,무추출물분말,치킨스톡P,에이치브이피에이치알,알파콘씨,가쓰오부시분말1.85%가다랑어100%(인도네시아산),건대파후레이크,정제팜유,5`리보뉴클레오티드이나트륨,멸치가루,양파분말,청양고추 농축분말,효모추출물,무수구연산,호박산이나트륨,흑후추분말,올레오레진캪시컴
